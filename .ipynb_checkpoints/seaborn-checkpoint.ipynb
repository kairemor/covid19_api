# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as snb

# %%
cd ~/Downloads/
# Out:
# /home/kairemor/Downloads

# %%
ls *.csv
# Out:
#  covid_19_data.csv              LTBI_estimates_2020-03-14.csv
#  COVID19_line_list_data.csv     MDR_RR_TB_burden_estimates_2020-03-14.csv
#  COVID19_open_line_list.csv     Soccer_Data_Set.docx.csv
# 'credentials (1).csv'           TB_burden_age_sex_2020-03-14.csv
#  credentials.csv                TB_burden_countries_2020-03-14.csv
# 'CSV as at 13 March 2020.csv'   TB_data_dictionary_2020-03-14.csv
#  final_april_data.csv           time_series_covid_19_confirmed.csv
#  final_data.csv                 time_series_covid_19_deaths.csv
#  LF_data.csv                    time_series_covid_19_recovered.csv

# %%
df = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv")

# %%
df.head()
# Out:
#   Province/State  Country/Region      Lat      Long  1/22/20  1/23/20  \
# 0          Anhui  Mainland China  31.8257  117.2264        0        0
# 1        Beijing  Mainland China  40.1824  116.4142        0        0
# 2      Chongqing  Mainland China  30.0572  107.8740        0        0
# 3         Fujian  Mainland China  26.0789  117.9874        0        0
# 4          Gansu  Mainland China  36.0611  103.8343        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  3/2/20  3/3/20  3/4/20  3/5/20  \
# 0        0        0        0        0  ...     917     936     956     970
# 1        1        2        2        2  ...     282     288     297     297
# 2        0        0        0        0  ...     469     490     502     512
# 3        0        0        0        0  ...     255     260     270     277
# 4        0        0        0        0  ...      85      86      87      87
#
#    3/6/20  3/7/20  3/8/20  3/9/20  3/10/20  3/11/20
# ...

# %%
snb.relplot(x="Province/State", y="1/22/20", data=df)

# %%
 df.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20', '1/28/20', '1/29/20',
#        '1/30/20', '1/31/20', '2/1/20', '2/2/20', '2/3/20', '2/4/20', '2/5/20',
#        '2/6/20', '2/7/20', '2/8/20', '2/9/20', '2/10/20', '2/11/20', '2/12/20',
#        '2/13/20', '2/14/20', '2/15/20', '2/16/20', '2/17/20', '2/18/20',
#        '2/19/20', '2/20/20', '2/21/20', '2/22/20', '2/23/20', '2/24/20',
#        '2/25/20', '2/26/20', '2/27/20', '2/28/20', '2/29/20', '3/1/20',
#        '3/2/20', '3/3/20', '3/4/20', '3/5/20', '3/6/20', '3/7/20', '3/8/20',
#        '3/9/20', '3/10/20', '3/11/20'],
#       dtype='object')

# %%
state = "Anhui"

# %%
columns_name = [column for column in df.columns if str(column).endswith('20')]

# %%
columns_name
# Out:
# ['1/22/20',
#  '1/23/20',
#  '1/24/20',
#  '1/25/20',
#  '1/26/20',
#  '1/27/20',
#  '1/28/20',
#  '1/29/20',
#  '1/30/20',
#  '1/31/20',
#  '2/1/20',
#  '2/2/20',
#  '2/3/20',
#  '2/4/20',
#  '2/5/20',
#  '2/6/20',
#  '2/7/20',
#  '2/8/20',
#  '2/9/20',
#  '2/10/20',
#  '2/11/20',
#  '2/12/20',
#  '2/13/20',
#  '2/14/20',
#  '2/15/20',
#  '2/16/20',
#  '2/17/20',
#  '2/18/20',
#  '2/19/20',
#  '2/20/20',
#  '2/21/20',
#  '2/22/20',
#  '2/23/20',
#  '2/24/20',
#  '2/25/20',
#  '2/26/20',
#  '2/27/20',
#  '2/28/20',
#  '2/29/20',
#  '3/1/20',
#  '3/2/20',
#  '3/3/20',
#  '3/4/20',
#  '3/5/20',
#  '3/6/20',
#  '3/7/20',
#  '3/8/20',
#  '3/9/20',
#  '3/10/20',
#  '3/11/20']

# %%
value = df.loc[0][4:]

# %%
value
# Out:
# 1/22/20      0
# 1/23/20      0
# 1/24/20      0
# 1/25/20      0
# 1/26/20      0
# 1/27/20      0
# 1/28/20      0
# 1/29/20      2
# 1/30/20      2
# 1/31/20      3
# 2/1/20       5
# 2/2/20       7
# 2/3/20      14
# 2/4/20      20
# 2/5/20      23
# 2/6/20      34
# 2/7/20      47
# 2/8/20      59
# 2/9/20      72
# 2/10/20     88
# 2/11/20    105
# 2/12/20    127
# 2/13/20    157
# 2/14/20    193
# 2/15/20    221
# 2/16/20    255
# 2/17/20    280
# 2/18/20    361
# 2/19/20    413
# 2/20/20    474
# 2/21/20    539
# 2/22/20    597
# 2/23/20    637
# 2/24/20    663
# 2/25/20    712
# 2/26/20    744
# 2/27/20    792
# 2/28/20    821
# 2/29/20    868
# 3/1/20     873
# 3/2/20     917
# 3/3/20     936
# 3/4/20     956
# 3/5/20     970
# 3/6/20     979
# 3/7/20     979
# 3/8/20     984
# 3/9/20     984
# 3/10/20    984
# 3/11/20    NaN
# Name: 0, dtype: object

# %%
df1 = pd.DataFrame({"day": columns_name, "value":value})

# %%
df1
# Out:
#              day value
# 1/22/20  1/22/20     0
# 1/23/20  1/23/20     0
# 1/24/20  1/24/20     0
# 1/25/20  1/25/20     0
# 1/26/20  1/26/20     0
# 1/27/20  1/27/20     0
# 1/28/20  1/28/20     0
# 1/29/20  1/29/20     2
# 1/30/20  1/30/20     2
# 1/31/20  1/31/20     3
# 2/1/20    2/1/20     5
# 2/2/20    2/2/20     7
# 2/3/20    2/3/20    14
# 2/4/20    2/4/20    20
# 2/5/20    2/5/20    23
# 2/6/20    2/6/20    34
# 2/7/20    2/7/20    47
# 2/8/20    2/8/20    59
# 2/9/20    2/9/20    72
# 2/10/20  2/10/20    88
# 2/11/20  2/11/20   105
# 2/12/20  2/12/20   127
# 2/13/20  2/13/20   157
# 2/14/20  2/14/20   193
# 2/15/20  2/15/20   221
# 2/16/20  2/16/20   255
# 2/17/20  2/17/20   280
# 2/18/20  2/18/20   361
# 2/19/20  2/19/20   413
# 2/20/20  2/20/20   474
# 2/21/20  2/21/20   539
# 2/22/20  2/22/20   597
# 2/23/20  2/23/20   637
# 2/24/20  2/24/20   663
# 2/25/20  2/25/20   712
# 2/26/20  2/26/20   744
# 2/27/20  2/27/20   792
# 2/28/20  2/28/20   821
# 2/29/20  2/29/20   868
# ...

# %%
value = df.loc[0][4:]

# %%
plt_snb = snb.relplot(x="day", y="value", data=df1)

# %%
plt_snb.savefig("ok.png")

# %%
snb.catplot(x="Province/State", y="3/3/20", kind="violin", data=df)

# %%
ls /home/kairemor/Downloads/*.csv
# Out:
#  /home/kairemor/Downloads/covid_19_data.csv
#  /home/kairemor/Downloads/COVID19_line_list_data.csv
#  /home/kairemor/Downloads/COVID19_open_line_list.csv
# '/home/kairemor/Downloads/credentials (1).csv'
#  /home/kairemor/Downloads/credentials.csv
# '/home/kairemor/Downloads/CSV as at 13 March 2020.csv'
#  /home/kairemor/Downloads/final_april_data.csv
#  /home/kairemor/Downloads/final_data.csv
#  /home/kairemor/Downloads/LF_data.csv
#  /home/kairemor/Downloads/LTBI_estimates_2020-03-14.csv
#  /home/kairemor/Downloads/MDR_RR_TB_burden_estimates_2020-03-14.csv
#  /home/kairemor/Downloads/Soccer_Data_Set.docx.csv
#  /home/kairemor/Downloads/TB_burden_age_sex_2020-03-14.csv
#  /home/kairemor/Downloads/TB_burden_countries_2020-03-14.csv
#  /home/kairemor/Downloads/TB_data_dictionary_2020-03-14.csv
#  /home/kairemor/Downloads/time_series_covid_19_confirmed.csv
#  /home/kairemor/Downloads/time_series_covid_19_deaths.csv
#  /home/kairemor/Downloads/time_series_covid_19_recovered.csv

# %%
df3 = pd.read_csv("/home/kairemor/Downloads/COVID19_open_line_list.csv")

# %%
df3
# Out:
#          ID  age     sex                        city province country  \
# 0       1.0   30    male     Chaohu City, Hefei City    Anhui   China
# 1       2.0   47    male  Baohe District, Hefei City    Anhui   China
# 2       3.0   49    male  High-Tech Zone, Hefei City    Anhui   China
# 3       4.0   47  female  High-Tech Zone, Hefei City    Anhui   China
# 4       5.0   50  female  Feidong County, Hefei City    Anhui   China
# 5       6.0  NaN     NaN                  Lu'an City    Anhui   China
# 6       7.0   42  female                 Fuyang City    Anhui   China
# 7       8.0  NaN  female                Huaibei City    Anhui   China
# 8       9.0   59  female                Huainan City    Anhui   China
# 9      10.0   30    male                  Hefei City    Anhui   China
# 10     11.0  NaN     NaN                  Lu'an City    Anhui   China
# 11     12.0   39    male                 Fuyang City    Anhui   China
# ...

# %%
df3.loc[df3["Province/State"] == 'Anhui']
# Out:
#        SNo ObservationDate Province/State  Country/Region  \
# 0        1      01/22/2020          Anhui  Mainland China
# 38      39      01/23/2020          Anhui  Mainland China
# 95      96      01/24/2020          Anhui  Mainland China
# 131    132      01/25/2020          Anhui  Mainland China
# 176    177      01/26/2020          Anhui  Mainland China
# 225    226      01/27/2020          Anhui  Mainland China
# 274    275      01/28/2020          Anhui  Mainland China
# 324    325      01/29/2020          Anhui  Mainland China
# 378    379      01/30/2020          Anhui  Mainland China
# 437    438      01/31/2020          Anhui  Mainland China
# 498    499        02/01/20          Anhui  Mainland China
# 565    566        02/02/20          Anhui  Mainland China
# 632    633        02/03/20          Anhui  Mainland China
# 700    701        02/04/20          Anhui  Mainland China
# 771    772        02/05/20          Anhui  Mainland China
# ...

# %%
snb.gr
# Out:
# Empty DataFrame
# Columns: [ID, age, sex, city, province, country, wuhan(0)_not_wuhan(1), latitude, longitude, geo_resolution, date_onset_symptoms, date_admission_hospital, date_confirmation, symptoms, lives_in_Wuhan, travel_history_dates, travel_history_location, reported_market_exposure, additional_information, chronic_disease_binary, chronic_disease, source, sequence_available, outcome, date_death_or_discharge, notes_for_discussion, location, admin3, admin2, admin1, country_new, admin_id, data_moderator_initials, Unnamed: 33, Unnamed: 34, Unnamed: 35, Unnamed: 36, Unnamed: 37, Unnamed: 38, Unnamed: 39, Unnamed: 40, Unnamed: 41, Unnamed: 42, Unnamed: 43, Unnamed: 44]
# Index: []
#
# [0 rows x 45 columns]

# %%
pays = set(df3['Country/Region'])

# %%
df2 = df3.loc[df3['Country/Region'] == "Senegal"].values

# %%
type(df2)
# Out:
# numpy.ndarray

# %%
columns_name = [column for column in df3.columns if str(column).endswith('20')]

# %%
os.chdir("image")

# %%
cd ~/Downloads/
# Out:
# /home/kairemor/Downloads

# %%
len(pays)/4
# Out:
# 33.0

# %%
fig, axes = plt.subplots(33,4)
for pay in pays :
    df2 = df3.loc[df3['Country/Region'] == pay]
    value = df2.values[0][4:]
    df1 = pd.DataFrame({"day"+pay: columns_name, "value":value})
    sns_plot = snb.relplot(x="day"+pay, y="value", data=df1)
    sns_plot.savefig(pay+".png")
# Out:
# /home/kairemor/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:311: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame
